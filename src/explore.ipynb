# %% [markdown]
# # Explore here
#
# It's recommended to use this notebook for exploration purposes.
#
# For example:
#
# 1. You could import the CSV generated by python into your notebook and explore it.
# 2. You could connect to your database using `pandas.read_sql` from this notebook and explore it.

# %%
# %pip install pandas
# %pip install matplotlib
# %pip install seaborn
# %pip install plotly
# %pip install sklearn
# %pip install statsmodels
# %pip install folium
# Out:
# Collecting pandas
#   Downloading pandas-1.4.3-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (11.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.7/11.7 MB 42.7 MB/s eta 0:00:0000:010:01
# Collecting numpy>=1.18.5
#   Downloading numpy-1.23.1-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (17.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 17.1/17.1 MB 31.0 MB/s eta 0:00:0000:0100:01
# Requirement already satisfied: python-dateutil>=2.8.1 in /home/gitpod/.pyenv/versions/3.8.13/lib/python3.8/site-packages (from pandas) (2.8.2)
# Collecting pytz>=2020.1
#   Downloading pytz-2022.1-py2.py3-none-any.whl (503 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 503.5/503.5 kB 25.8 MB/s eta 0:00:00
# Requirement already satisfied: six>=1.5 in /home/gitpod/.pyenv/versions/3.8.13/lib/python3.8/site-packages (from python-dateutil>=2.8.1->pandas) (1.16.0)
# Installing collected packages: pytz, numpy, pandas
# Successfully installed numpy-1.23.1 pandas-1.4.3 pytz-2022.1
#
# [notice] A new release of pip available: 22.1.2 -> 22.2
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.
# Collecting matplotlib
#   Downloading matplotlib-3.5.2-cp38-cp38-manylinux_2_5_x86_64.manylinux1_x86_64.whl (11.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.3/11.3 MB 42.9 MB/s eta 0:00:0000:010:01
# Collecting kiwisolver>=1.0.1
#   Downloading kiwisolver-1.4.4-cp38-cp38-manylinux_2_5_x86_64.manylinux1_x86_64.whl (1.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 60.6 MB/s eta 0:00:00
# Collecting pillow>=6.2.0
#   Downloading Pillow-9.2.0-cp38-cp38-manylinux_2_28_x86_64.whl (3.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.2/3.2 MB 39.7 MB/s eta 0:00:00:00:01
# Requirement already satisfied: pyparsing>=2.2.1 in /home/gitpod/.pyenv/versions/3.8.13/lib/python3.8/site-packages (from matplotlib) (3.0.9)
# Requirement already satisfied: packaging>=20.0 in /home/gitpod/.pyenv/versions/3.8.13/lib/python3.8/site-packages (from matplotlib) (21.3)
# Requirement already satisfied: numpy>=1.17 in /home/gitpod/.pyenv/versions/3.8.13/lib/python3.8/site-packages (from matplotlib) (1.23.1)
# Requirement already satisfied: python-dateutil>=2.7 in /home/gitpod/.pyenv/versions/3.8.13/lib/python3.8/site-packages (from matplotlib) (2.8.2)
# Collecting fonttools>=4.22.0
#   Downloading fonttools-4.34.4-py3-none-any.whl (944 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 944.1/944.1 kB 43.2 MB/s eta 0:00:00
# Collecting cycler>=0.10
#   Downloading cycler-0.11.0-py3-none-any.whl (6.4 kB)
# Requirement already satisfied: six>=1.5 in /home/gitpod/.pyenv/versions/3.8.13/lib/python3.8/site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# Installing collected packages: pillow, kiwisolver, fonttools, cycler, matplotlib
# Successfully installed cycler-0.11.0 fonttools-4.34.4 kiwisolver-1.4.4 matplotlib-3.5.2 pillow-9.2.0
#
# [notice] A new release of pip available: 22.1.2 -> 22.2
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.
# Collecting seaborn
#   Downloading seaborn-0.11.2-py3-none-any.whl (292 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 292.8/292.8 kB 6.4 MB/s eta 0:00:0000:01
# Requirement already satisfied: matplotlib>=2.2 in /home/gitpod/.pyenv/versions/3.8.13/lib/python3.8/site-packages (from seaborn) (3.5.2)
# Requirement already satisfied: numpy>=1.15 in /home/gitpod/.pyenv/versions/3.8.13/lib/python3.8/site-packages (from seaborn) (1.23.1)
# Requirement already satisfied: pandas>=0.23 in /home/gitpod/.pyenv/versions/3.8.13/lib/python3.8/site-packages (from seaborn) (1.4.3)
# Collecting scipy>=1.0
#   Downloading scipy-1.8.1-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (41.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 41.6/41.6 MB 17.3 MB/s eta 0:00:0000:0100:01
# Requirement already satisfied: pillow>=6.2.0 in /home/gitpod/.pyenv/versions/3.8.13/lib/python3.8/site-packages (from matplotlib>=2.2->seaborn) (9.2.0)
# Requirement already satisfied: fonttools>=4.22.0 in /home/gitpod/.pyenv/versions/3.8.13/lib/python3.8/site-packages (from matplotlib>=2.2->seaborn) (4.34.4)
# Requirement already satisfied: python-dateutil>=2.7 in /home/gitpod/.pyenv/versions/3.8.13/lib/python3.8/site-packages (from matplotlib>=2.2->seaborn) (2.8.2)
# Requirement already satisfied: pyparsing>=2.2.1 in /home/gitpod/.pyenv/versions/3.8.13/lib/python3.8/site-packages (from matplotlib>=2.2->seaborn) (3.0.9)
# Requirement already satisfied: cycler>=0.10 in /home/gitpod/.pyenv/versions/3.8.13/lib/python3.8/site-packages (from matplotlib>=2.2->seaborn) (0.11.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /home/gitpod/.pyenv/versions/3.8.13/lib/python3.8/site-packages (from matplotlib>=2.2->seaborn) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in /home/gitpod/.pyenv/versions/3.8.13/lib/python3.8/site-packages (from matplotlib>=2.2->seaborn) (21.3)
# Requirement already satisfied: pytz>=2020.1 in /home/gitpod/.pyenv/versions/3.8.13/lib/python3.8/site-packages (from pandas>=0.23->seaborn) (2022.1)
# Requirement already satisfied: six>=1.5 in /home/gitpod/.pyenv/versions/3.8.13/lib/python3.8/site-packages (from python-dateutil>=2.7->matplotlib>=2.2->seaborn) (1.16.0)
# Installing collected packages: scipy, seaborn
# Successfully installed scipy-1.8.1 seaborn-0.11.2
#
# [notice] A new release of pip available: 22.1.2 -> 22.2
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.
# Collecting plotly
#   Downloading plotly-5.9.0-py2.py3-none-any.whl (15.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 15.2/15.2 MB 46.0 MB/s eta 0:00:0000:0100:01
# Collecting tenacity>=6.2.0
#   Downloading tenacity-8.0.1-py3-none-any.whl (24 kB)
# Installing collected packages: tenacity, plotly
# Successfully installed plotly-5.9.0 tenacity-8.0.1
#
# [notice] A new release of pip available: 22.1.2 -> 22.2
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.
# Collecting sklearn
#   Downloading sklearn-0.0.tar.gz (1.1 kB)
#   Preparing metadata (setup.py) ... done
# Collecting scikit-learn
#   Downloading scikit_learn-1.1.1-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (31.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 31.2/31.2 MB 19.7 MB/s eta 0:00:0000:0100:01
# Collecting threadpoolctl>=2.0.0
#   Downloading threadpoolctl-3.1.0-py3-none-any.whl (14 kB)
# Requirement already satisfied: numpy>=1.17.3 in /home/gitpod/.pyenv/versions/3.8.13/lib/python3.8/site-packages (from scikit-learn->sklearn) (1.23.1)
# Collecting joblib>=1.0.0
#   Downloading joblib-1.1.0-py2.py3-none-any.whl (306 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 307.0/307.0 kB 15.5 MB/s eta 0:00:00
# Requirement already satisfied: scipy>=1.3.2 in /home/gitpod/.pyenv/versions/3.8.13/lib/python3.8/site-packages (from scikit-learn->sklearn) (1.8.1)
# Building wheels for collected packages: sklearn
#   Building wheel for sklearn (setup.py) ... done
#   Created wheel for sklearn: filename=sklearn-0.0-py2.py3-none-any.whl size=1304 sha256=3ed9946b5993ad84bc93ad952cd2d1daa4de221760ba27edd330019eaefc40c2
#   Stored in directory: /home/gitpod/.cache/pip/wheels/22/0b/40/fd3f795caaa1fb4c6cb738bc1f56100be1e57da95849bfc897
# Successfully built sklearn
# Installing collected packages: threadpoolctl, joblib, scikit-learn, sklearn
# Successfully installed joblib-1.1.0 scikit-learn-1.1.1 sklearn-0.0 threadpoolctl-3.1.0
#
# [notice] A new release of pip available: 22.1.2 -> 22.2
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.
# Collecting statsmodels
#   Downloading statsmodels-0.13.2-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (9.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.9/9.9 MB 51.4 MB/s eta 0:00:0000:0100:01
# Requirement already satisfied: numpy>=1.17 in /home/gitpod/.pyenv/versions/3.8.13/lib/python3.8/site-packages (from statsmodels) (1.23.1)
# Collecting patsy>=0.5.2
#   Downloading patsy-0.5.2-py2.py3-none-any.whl (233 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 233.7/233.7 kB 22.8 MB/s eta 0:00:00
# Requirement already satisfied: packaging>=21.3 in /home/gitpod/.pyenv/versions/3.8.13/lib/python3.8/site-packages (from statsmodels) (21.3)
# Requirement already satisfied: pandas>=0.25 in /home/gitpod/.pyenv/versions/3.8.13/lib/python3.8/site-packages (from statsmodels) (1.4.3)
# Requirement already satisfied: scipy>=1.3 in /home/gitpod/.pyenv/versions/3.8.13/lib/python3.8/site-packages (from statsmodels) (1.8.1)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /home/gitpod/.pyenv/versions/3.8.13/lib/python3.8/site-packages (from packaging>=21.3->statsmodels) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.8.1 in /home/gitpod/.pyenv/versions/3.8.13/lib/python3.8/site-packages (from pandas>=0.25->statsmodels) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /home/gitpod/.pyenv/versions/3.8.13/lib/python3.8/site-packages (from pandas>=0.25->statsmodels) (2022.1)
# Requirement already satisfied: six in /home/gitpod/.pyenv/versions/3.8.13/lib/python3.8/site-packages (from patsy>=0.5.2->statsmodels) (1.16.0)
# Installing collected packages: patsy, statsmodels
# Successfully installed patsy-0.5.2 statsmodels-0.13.2
#
# [notice] A new release of pip available: 22.1.2 -> 22.2
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.
# Collecting folium
#   Downloading folium-0.12.1.post1-py2.py3-none-any.whl (95 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 95.0/95.0 kB 4.8 MB/s eta 0:00:00
# Requirement already satisfied: requests in /home/gitpod/.pyenv/versions/3.8.13/lib/python3.8/site-packages (from folium) (2.28.0)
# Requirement already satisfied: numpy in /home/gitpod/.pyenv/versions/3.8.13/lib/python3.8/site-packages (from folium) (1.23.1)
# Collecting branca>=0.3.0
#   Downloading branca-0.5.0-py3-none-any.whl (24 kB)
# Requirement already satisfied: jinja2>=2.9 in /home/gitpod/.pyenv/versions/3.8.13/lib/python3.8/site-packages (from folium) (3.1.2)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/gitpod/.pyenv/versions/3.8.13/lib/python3.8/site-packages (from jinja2>=2.9->folium) (2.1.1)
# Requirement already satisfied: certifi>=2017.4.17 in /home/gitpod/.pyenv/versions/3.8.13/lib/python3.8/site-packages (from requests->folium) (2022.6.15)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /home/gitpod/.pyenv/versions/3.8.13/lib/python3.8/site-packages (from requests->folium) (2.0.12)
# Requirement already satisfied: idna<4,>=2.5 in /home/gitpod/.pyenv/versions/3.8.13/lib/python3.8/site-packages (from requests->folium) (3.3)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /home/gitpod/.pyenv/versions/3.8.13/lib/python3.8/site-packages (from requests->folium) (1.26.9)
# Installing collected packages: branca, folium
# Successfully installed branca-0.5.0 folium-0.12.1.post1
#
# [notice] A new release of pip available: 22.1.2 -> 22.2
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import plotly.express as px
import folium
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import cross_val_score
from sklearn.metrics import confusion_matrix
from sklearn.metrics import ConfusionMatrixDisplay
from sklearn.metrics import classification_report
from sklearn.model_selection import GridSearchCV
from sklearn import tree
import pickle

# %%
url='https://raw.githubusercontent.com/4GeeksAcademy/decision-tree-project-tutorial/main/diabetes.csv'
df_raw=pd.read_csv(url)
df_raw.shape
# Out:
# (768, 9)

# %%
df_raw.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 768 entries, 0 to 767
# Data columns (total 9 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Pregnancies               768 non-null    int64
#  1   Glucose                   768 non-null    int64
#  2   BloodPressure             768 non-null    int64
#  3   SkinThickness             768 non-null    int64
#  4   Insulin                   768 non-null    int64
#  5   BMI                       768 non-null    float64
#  6   DiabetesPedigreeFunction  768 non-null    float64
#  7   Age                       768 non-null    int64
#  8   Outcome                   768 non-null    int64
# dtypes: float64(2), int64(7)
# memory usage: 54.1 KB

# %%
df_raw.sample(5)
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 541            3      128             72             25      190  32.4
# 197            3      107             62             13       48  22.9
# 252            2       90             80             14       55  24.4
# 178            5      143             78              0        0  45.0
# 426            0       94              0              0        0   0.0
#
#      DiabetesPedigreeFunction  Age  Outcome
# 541                     0.549   27        1
# 197                     0.678   23        1
# 252                     0.249   24        0
# 178                     0.190   47        0
# 426                     0.256   25        0

# %%
df_raw.describe()
# Out:
#        Pregnancies     Glucose  BloodPressure  SkinThickness     Insulin  \
# count   768.000000  768.000000     768.000000     768.000000  768.000000
# mean      3.845052  120.894531      69.105469      20.536458   79.799479
# std       3.369578   31.972618      19.355807      15.952218  115.244002
# min       0.000000    0.000000       0.000000       0.000000    0.000000
# 25%       1.000000   99.000000      62.000000       0.000000    0.000000
# 50%       3.000000  117.000000      72.000000      23.000000   30.500000
# 75%       6.000000  140.250000      80.000000      32.000000  127.250000
# max      17.000000  199.000000     122.000000      99.000000  846.000000
#
#               BMI  DiabetesPedigreeFunction         Age     Outcome
# count  768.000000                768.000000  768.000000  768.000000
# mean    31.992578                  0.471876   33.240885    0.348958
# std      7.884160                  0.331329   11.760232    0.476951
# min      0.000000                  0.078000   21.000000    0.000000
# 25%     27.300000                  0.243750   24.000000    0.000000
# 50%     32.000000                  0.372500   29.000000    0.000000
# 75%     36.600000                  0.626250   41.000000    1.000000
# max     67.100000                  2.420000   81.000000    1.000000

# %%
df_filter = df_raw.copy()
df_filter = df_raw[(df_raw["BMI"] > 0 ) & (df_raw["BloodPressure"] > 0) & (df_raw["Glucose"] > 0)]
df_filter
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# 1                       0.351   31        0
# 2                       0.672   32        1
# 3                       0.167   21        0
# 4                       2.288   33        1
# ..                        ...  ...      ...
# 763                     0.171   63        0
# 764                     0.340   27        0
# 765                     0.245   30        0
# 766                     0.349   47        1
# 767                     0.315   23        0
#
# [724 rows x 9 columns]

# %% [markdown]
# Remuevo los valores que tienen BMI, BloodPressure y Glucose igual a 0. Aqui borro 44 observaciones

# %% [markdown]
# **EDA**

# %%
df = df_filter.copy()

# %%
# Split the dataset 

X = df.drop('Outcome', axis=1)
y = df['Outcome']

X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=208)

# %%
# Join the train sets to ease insights

df_train = pd.concat([X_train, y_train], axis=1)

# %%
# Get basic info

df_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 543 entries, 391 to 441
# Data columns (total 9 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Pregnancies               543 non-null    int64
#  1   Glucose                   543 non-null    int64
#  2   BloodPressure             543 non-null    int64
#  3   SkinThickness             543 non-null    int64
#  4   Insulin                   543 non-null    int64
#  5   BMI                       543 non-null    float64
#  6   DiabetesPedigreeFunction  543 non-null    float64
#  7   Age                       543 non-null    int64
#  8   Outcome                   543 non-null    int64
# dtypes: float64(2), int64(7)
# memory usage: 42.4 KB

# %%
# Describe the numerical and date variables

df_train.describe()
# Out:
#        Pregnancies     Glucose  BloodPressure  SkinThickness     Insulin  \
# count   543.000000  543.000000     543.000000     543.000000  543.000000
# mean      3.861878  122.340700      72.565378      21.305709   87.895028
# std       3.294477   31.384709      12.557868      15.872488  123.404706
# min       0.000000   44.000000      24.000000       0.000000    0.000000
# 25%       1.000000  100.000000      64.000000       0.000000    0.000000
# 50%       3.000000  118.000000      72.000000      23.000000   48.000000
# 75%       6.000000  143.000000      80.000000      33.000000  135.000000
# max      17.000000  197.000000     122.000000      99.000000  846.000000
#
#               BMI  DiabetesPedigreeFunction         Age     Outcome
# count  543.000000                543.000000  543.000000  543.000000
# mean    32.591713                  0.464265   33.552486    0.349908
# std      7.015333                  0.336704   11.767290    0.477380
# min     18.200000                  0.084000   21.000000    0.000000
# 25%     27.550000                  0.238000   24.000000    0.000000
# 50%     32.400000                  0.361000   29.000000    0.000000
# 75%     36.600000                  0.600000   41.000000    1.000000
# max     67.100000                  2.420000   68.000000    1.000000

# %%
# Take a sample

df_train.sample(10)
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 41             7      133             84              0        0  40.2
# 247            0      165             90             33      680  52.3
# 556            1       97             70             40        0  38.1
# 107            4      144             58             28      140  29.5
# 548            1      164             82             43       67  32.8
# 483            0       84             82             31      125  38.2
# 313            3      113             50             10       85  29.5
# 360            5      189             64             33      325  31.2
# 280            0      146             70              0        0  37.9
# 600            1      108             88             19        0  27.1
#
#      DiabetesPedigreeFunction  Age  Outcome
# 41                      0.696   37        0
# 247                     0.427   23        0
# 556                     0.218   30        0
# 107                     0.287   37        0
# 548                     0.341   50        0
# 483                     0.233   23        0
# 313                     0.626   25        0
# 360                     0.583   29        1
# 280                     0.334   28        1
# 600                     0.400   24        0

# %%
# Perform univariate analysis - histograms

X_train.hist(figsize=(8,8), alpha=0.5)
plt.show()

# %%
# Perform univariate analysis - boxplots

fig, ax = plt.subplots(2,4, figsize=(8,4))
axs = ax.flatten()
for i in range(len(axs)):
    X_train._get_numeric_data().iloc[:,i].to_frame().boxplot(ax=axs[i])

# %%
# Perform bivariate analysis - numericals

pd.plotting.scatter_matrix(X_train, diagonal='kde', figsize=(8,8), c='Violet')
plt.show()

# %%
sns.heatmap(X_train.corr(),annot=True)
# Out:
# <AxesSubplot:>

# %%
# Target variable

df_train['Outcome'].value_counts()
# Out:
# 0    353
# 1    190
# Name: Outcome, dtype: int64

# %%
# Analyze effect on response variable (DV)

df_train.corr().style.background_gradient(cmap='Blues')
# Out:
# <style type="text/css">
# #T_27240_row0_col0, #T_27240_row1_col1, #T_27240_row2_col2, #T_27240_row3_col3, #T_27240_row4_col4, #T_27240_row5_col5, #T_27240_row6_col6, #T_27240_row7_col7, #T_27240_row8_col8 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_27240_row0_col1 {
#   background-color: #f3f8fe;
#   color: #000000;
# }
# #T_27240_row0_col2, #T_27240_row2_col0, #T_27240_row8_col6 {
#   background-color: #c9ddf0;
#   color: #000000;
# }
# #T_27240_row0_col3 {
#   background-color: #eff6fc;
#   color: #000000;
# }
# #T_27240_row0_col4, #T_27240_row2_col6 {
#   background-color: #f6faff;
#   color: #000000;
# }
# #T_27240_row0_col5, #T_27240_row0_col6, #T_27240_row2_col4, #T_27240_row3_col0, #T_27240_row3_col1, #T_27240_row3_col7, #T_27240_row3_col8, #T_27240_row4_col2, #T_27240_row7_col3 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# #T_27240_row0_col7 {
#   background-color: #4b98ca;
#   color: #f1f1f1;
# }
# #T_27240_row0_col8 {
#   background-color: #e2edf8;
#   color: #000000;
# }
# #T_27240_row1_col0, #T_27240_row4_col6 {
#   background-color: #d0e1f2;
#   color: #000000;
# }
# #T_27240_row1_col2 {
#   background-color: #bdd7ec;
#   color: #000000;
# }
# #T_27240_row1_col3 {
#   background-color: #cddff1;
#   color: #000000;
# }
# #T_27240_row1_col4 {
#   background-color: #8fc2de;
#   color: #000000;
# }
# #T_27240_row1_col5 {
#   background-color: #cde0f1;
#   color: #000000;
# }
# #T_27240_row1_col6, #T_27240_row6_col5 {
#   background-color: #d1e2f3;
#   color: #000000;
# }
# #T_27240_row1_col7 {
#   background-color: #a5cde3;
#   color: #000000;
# }
# #T_27240_row1_col8 {
#   background-color: #85bcdc;
#   color: #000000;
# }
# #T_27240_row2_col1 {
#   background-color: #dfecf7;
#   color: #000000;
# }
# #T_27240_row2_col3 {
#   background-color: #dfebf7;
#   color: #000000;
# }
# #T_27240_row2_col5 {
#   background-color: #b7d4ea;
#   color: #000000;
# }
# #T_27240_row2_col7 {
#   background-color: #8dc1dd;
#   color: #000000;
# }
# #T_27240_row2_col8, #T_27240_row4_col8, #T_27240_row7_col5 {
#   background-color: #eef5fc;
#   color: #000000;
# }
# #T_27240_row3_col2 {
#   background-color: #e7f1fa;
#   color: #000000;
# }
# #T_27240_row3_col4 {
#   background-color: #81badb;
#   color: #000000;
# }
# #T_27240_row3_col5 {
#   background-color: #95c5df;
#   color: #000000;
# }
# #T_27240_row3_col6 {
#   background-color: #d6e6f4;
#   color: #000000;
# }
# #T_27240_row4_col0 {
#   background-color: #f5fafe;
#   color: #000000;
# }
# #T_27240_row4_col1 {
#   background-color: #bad6eb;
#   color: #000000;
# }
# #T_27240_row4_col3 {
#   background-color: #77b5d9;
#   color: #000000;
# }
# #T_27240_row4_col5, #T_27240_row5_col8 {
#   background-color: #d2e3f3;
#   color: #000000;
# }
# #T_27240_row4_col7 {
#   background-color: #eaf3fb;
#   color: #000000;
# }
# #T_27240_row5_col0 {
#   background-color: #e8f1fa;
#   color: #000000;
# }
# #T_27240_row5_col1 {
#   background-color: #e1edf8;
#   color: #000000;
# }
# #T_27240_row5_col2 {
#   background-color: #a6cee4;
#   color: #000000;
# }
# #T_27240_row5_col3 {
#   background-color: #79b5d9;
#   color: #000000;
# }
# #T_27240_row5_col4 {
#   background-color: #c7dbef;
#   color: #000000;
# }
# #T_27240_row5_col6, #T_27240_row8_col2, #T_27240_row8_col4 {
#   background-color: #cee0f2;
#   color: #000000;
# }
# #T_27240_row5_col7, #T_27240_row7_col8 {
#   background-color: #d9e8f5;
#   color: #000000;
# }
# #T_27240_row6_col0 {
#   background-color: #ecf4fb;
#   color: #000000;
# }
# #T_27240_row6_col1 {
#   background-color: #e9f2fa;
#   color: #000000;
# }
# #T_27240_row6_col2 {
#   background-color: #ebf3fb;
#   color: #000000;
# }
# #T_27240_row6_col3, #T_27240_row6_col4 {
#   background-color: #c7dcef;
#   color: #000000;
# }
# #T_27240_row6_col7, #T_27240_row6_col8 {
#   background-color: #ddeaf7;
#   color: #000000;
# }
# #T_27240_row7_col0 {
#   background-color: #519ccc;
#   color: #f1f1f1;
# }
# #T_27240_row7_col1 {
#   background-color: #d4e4f4;
#   color: #000000;
# }
# #T_27240_row7_col2 {
#   background-color: #9ac8e0;
#   color: #000000;
# }
# #T_27240_row7_col4 {
#   background-color: #f4f9fe;
#   color: #000000;
# }
# #T_27240_row7_col6 {
#   background-color: #f0f6fd;
#   color: #000000;
# }
# #T_27240_row8_col0 {
#   background-color: #c3daee;
#   color: #000000;
# }
# #T_27240_row8_col1 {
#   background-color: #89bedc;
#   color: #000000;
# }
# #T_27240_row8_col3 {
#   background-color: #cfe1f2;
#   color: #000000;
# }
# #T_27240_row8_col5 {
#   background-color: #bfd8ed;
#   color: #000000;
# }
# #T_27240_row8_col7 {
#   background-color: #aed1e7;
#   color: #000000;
# }
# </style>
# <table id="T_27240">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_27240_level0_col0" class="col_heading level0 col0" >Pregnancies</th>
#       <th id="T_27240_level0_col1" class="col_heading level0 col1" >Glucose</th>
#       <th id="T_27240_level0_col2" class="col_heading level0 col2" >BloodPressure</th>
#       <th id="T_27240_level0_col3" class="col_heading level0 col3" >SkinThickness</th>
#       <th id="T_27240_level0_col4" class="col_heading level0 col4" >Insulin</th>
#       <th id="T_27240_level0_col5" class="col_heading level0 col5" >BMI</th>
#       <th id="T_27240_level0_col6" class="col_heading level0 col6" >DiabetesPedigreeFunction</th>
#       <th id="T_27240_level0_col7" class="col_heading level0 col7" >Age</th>
#       <th id="T_27240_level0_col8" class="col_heading level0 col8" >Outcome</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_27240_level0_row0" class="row_heading level0 row0" >Pregnancies</th>
#       <td id="T_27240_row0_col0" class="data row0 col0" >1.000000</td>
#       <td id="T_27240_row0_col1" class="data row0 col1" >0.141032</td>
#       <td id="T_27240_row0_col2" class="data row0 col2" >0.181614</td>
#       <td id="T_27240_row0_col3" class="data row0 col3" >-0.074380</td>
#       <td id="T_27240_row0_col4" class="data row0 col4" >-0.063679</td>
#       <td id="T_27240_row0_col5" class="data row0 col5" >0.006720</td>
#       <td id="T_27240_row0_col6" class="data row0 col6" >-0.011776</td>
#       <td id="T_27240_row0_col7" class="data row0 col7" >0.548761</td>
#       <td id="T_27240_row0_col8" class="data row0 col8" >0.206758</td>
#     </tr>
#     <tr>
#       <th id="T_27240_level0_row1" class="row_heading level0 row1" >Glucose</th>
#       <td id="T_27240_row1_col0" class="data row1 col0" >0.141032</td>
#       <td id="T_27240_row1_col1" class="data row1 col1" >1.000000</td>
#       <td id="T_27240_row1_col2" class="data row1 col2" >0.226965</td>
#       <td id="T_27240_row1_col3" class="data row1 col3" >0.120854</td>
#       <td id="T_27240_row1_col4" class="data row1 col4" >0.371774</td>
#       <td id="T_27240_row1_col5" class="data row1 col5" >0.219716</td>
#       <td id="T_27240_row1_col6" class="data row1 col6" >0.185622</td>
#       <td id="T_27240_row1_col7" class="data row1 col7" >0.277676</td>
#       <td id="T_27240_row1_col8" class="data row1 col8" >0.495939</td>
#     </tr>
#     <tr>
#       <th id="T_27240_level0_row2" class="row_heading level0 row2" >BloodPressure</th>
#       <td id="T_27240_row2_col0" class="data row2 col0" >0.181614</td>
#       <td id="T_27240_row2_col1" class="data row2 col1" >0.226965</td>
#       <td id="T_27240_row2_col2" class="data row2 col2" >1.000000</td>
#       <td id="T_27240_row2_col3" class="data row2 col3" >0.015515</td>
#       <td id="T_27240_row2_col4" class="data row2 col4" >-0.069931</td>
#       <td id="T_27240_row2_col5" class="data row2 col5" >0.305147</td>
#       <td id="T_27240_row2_col6" class="data row2 col6" >-0.006090</td>
#       <td id="T_27240_row2_col7" class="data row2 col7" >0.343670</td>
#       <td id="T_27240_row2_col8" class="data row2 col8" >0.154369</td>
#     </tr>
#     <tr>
#       <th id="T_27240_level0_row3" class="row_heading level0 row3" >SkinThickness</th>
#       <td id="T_27240_row3_col0" class="data row3 col0" >-0.074380</td>
#       <td id="T_27240_row3_col1" class="data row3 col1" >0.120854</td>
#       <td id="T_27240_row3_col2" class="data row3 col2" >0.015515</td>
#       <td id="T_27240_row3_col3" class="data row3 col3" >1.000000</td>
#       <td id="T_27240_row3_col4" class="data row3 col4" >0.407616</td>
#       <td id="T_27240_row3_col5" class="data row3 col5" >0.402478</td>
#       <td id="T_27240_row3_col6" class="data row3 col6" >0.154991</td>
#       <td id="T_27240_row3_col7" class="data row3 co

# %% [markdown]
# La glucosa y el BMI tienen una correlación relativamente alta con la variable objetivo.

# %%
sns.boxplot(x="Outcome", y="Glucose", data=df_train)
# Out:
# <AxesSubplot:xlabel='Outcome', ylabel='Glucose'>

# %%
sns.boxplot(x="Outcome", y="BMI", data=df_train)
# Out:
# <AxesSubplot:xlabel='Outcome', ylabel='BMI'>

# %% [markdown]
# La glucosa parece ser una característica útil para separar a las personas con y sin diabetes.

# %% [markdown]
# **Decision Tree**

# %% [markdown]
# Model 1

# %%
clf = DecisionTreeClassifier(criterion='entropy',random_state=0)

clf.fit(X_train, y_train)

print('Accuracy model 1 - train set:', clf.score(X_train, y_train))
print('Accuracy model 1 - test set:', clf.score(X_test, y_test))
# Out:
# Accuracy model 1 - train set: 1.0
# Accuracy model 1 - test set: 0.6961325966850829

# %%
clf_pred=clf.predict(X_test)

# %%
cm = confusion_matrix(y_test, clf_pred, labels=clf.classes_)
disp = ConfusionMatrixDisplay(confusion_matrix=cm,
display_labels=clf.classes_)
disp.plot()

plt.show()

# %%
#Classification report - Model 1

print(classification_report(y_test,clf_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.78      0.76      0.77       122
#            1       0.53      0.56      0.55        59
#
#     accuracy                           0.70       181
#    macro avg       0.66      0.66      0.66       181
# weighted avg       0.70      0.70      0.70       181

# %%
plt.figure(figsize=(10,8))
tree.plot_tree(clf)
plt.show()

# %% [markdown]
# Este modelo parece sobreajustar los datos: el accuracy en X_train 100 %, mientras que en X_test el 70 %

# %% [markdown]
# Model 2: hyperparameters selection by crossvalidation

# %%
params = {'criterion': ['gini', 'entropy'], 'max_depth': range(1,10), 'min_samples_split':range(1,10), 'min_samples_leaf': range(1,5)}

grid = GridSearchCV(DecisionTreeClassifier(random_state=0), params, verbose=1, n_jobs=-1,cv=3)

grid.fit(X_train, y_train)
# Out:
# Fitting 3 folds for each of
#         nan 0.74585635 0.74585635 0.74585635 0.74585635 0.74585635
#  0.74585635 0.73848987 0.74033149        nan 0.74217311 0.74217311
#  0.74217311 0.74217311 0.74217311 0.74217311 0.74217311 0.74033149
#         nan 0.71086556 0.71270718 0.71270718 0.7145488  0.71639042
#  0.72191529 0.72375691 0.72191529        nan 0.7145488  0.7145488
#  0.7145488  0.7145488  0.7145488  0.72007366 0.72007366 0.71823204
#         nan 0.72191529 0.72191529 0.72191529 0.72191529 0.72191529
#  0.72744015 0.72191529 0.72191529        nan 0.72744015 0.72744015
#  0.72744015 0.72744015 0.72744015 0.72744015 0.72744015 0.72559853
#         nan 0.72559853 0.72191529 0.71823204 0.7145488  0.70718232
#  0.70718232 0.70165746 0.70718232        nan 0.72744015 0.72744015
#  0.72744015 0.71639042 0.71086556 0.71270718 0.7053407  0.71270718
#         nan 0.7145488  0.7145488  0.7145488  0.7145488  0.7145488
#  0.72191529 0.71823204 0.72744015        nan 0.69429098 0.69429098
#  0.69429098 0.69429098 0.69429098 0.69429098 0.69429098 0.70349908
#         nan 0.68876611 0.6961326  0.7053407  0.70718232 0.6961326
#  0.69429098 0.69244936 0.7053407         nan 0.71270718 0.71270718
#  0.71270718 0.70902394 0.6961326  0.69797422 0.69244936 0.69981584
#         nan 0.71086556 0.71086556 0.71086556 0.71086556 0.71086556
#  0.71270718 0.7053407  0.70902394        nan 0.71086556 0.71086556
#  0.71086556 0.71086556 0.71086556 0.71086556 0.71086556 0.7053407
#         nan 0.71086556 0.71086556 0.70718232 0.7053407  0.70165746
#  0.7053407  0.7053407  0.71639042        nan 0.72928177 0.72928177
#  0.72928177 0.70902394 0.71270718 0.71086556 0.7053407  0.7145488
#         nan 0.71086556 0.71086556 0.71086556 0.71086556 0.71086556
#  0.70165746 0.70349908 0.7145488         nan 0.6961326  0.6961326
#  0.6961326  0.6961326  0.6961326  0.6961326  0.6961326  0.70718232]
#   warnings.warn(
# GridSearchCV(cv=3, estimator=DecisionTreeClassifier(random_state=0), n_jobs=-1,
#              param_grid={'criterion': ['gini', 'entropy'],
#                          'max_depth': range(1, 10),
#                          'min_samples_leaf': range(1, 5),
#                          'min_samples_split': range(1, 10)},
#              verbose=1)

# %%
grid.best_params_
# Out:
# {'criterion': 'entropy',
#  'max_depth': 5,
#  'min_samples_leaf': 3,
#  'min_samples_split': 2}

# %%
model_cv = grid.best_estimator_

# %%
grid.best_score_
# Out:
# 0.7458563535911602

# %%
print('Accuracy model 2 - train set:',grid.score(X_train, y_train))

y_pred = model_cv.predict(X_test)

print('Accuracy model 2 - test set:',grid.score(X_test, y_test))
# Out:
# Accuracy model 2 - train set: 0.8121546961325967
# Accuracy model 2 - test set: 0.7513812154696132

# %%
cm = confusion_matrix(y_test, y_pred, labels=grid.classes_)
disp = ConfusionMatrixDisplay(confusion_matrix=cm,
display_labels=grid.classes_)
disp.plot()

plt.show()

# %%
#Classification report - Model 2
print(classification_report(y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.81      0.83      0.82       122
#            1       0.62      0.59      0.61        59
#
#     accuracy                           0.75       181
#    macro avg       0.72      0.71      0.71       181
# weighted avg       0.75      0.75      0.75       181

# %%
plt.figure(figsize=(10,8))
tree.plot_tree(model_cv)
plt.show()

# %%
# Save best model

filename = '../models/final_model.sav'
pickle.dump(model_cv, open(filename, 'wb'))

# %% [markdown]
# La optimizacion de hiperparametros por crossvalidation, ayudo a mejorar la accuracy a 75%.
# Quizas con un modelo de random forest podriamos mejorar las metricas aun mas en la prediccion de la diabetes
